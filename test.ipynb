# %% [markdown]
# # 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import string

df = pd.read_csv("data_2228.csv", index_col=0)

# Rename columns to letters: A, B, C, ...
df.columns = list(string.ascii_uppercase[:len(df.columns)])

# Correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap="coolwarm", center=0)
plt.title("Correlation Matrix")
plt.tight_layout()
plt.savefig("correlation_heatmap.png", dpi=150)
plt.show()

# Pairplot
g = sns.pairplot(df)
g.savefig("pairplot.png", dpi=150)
plt.show()

# %% [markdown]
# # 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import string

df = pd.read_csv("data_2237.csv", index_col=0)

# Rename columns to letters: A, B, C, ...
df.columns = list(string.ascii_uppercase[:len(df.columns)])

# Correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap="coolwarm", center=0)
plt.title("Correlation Matrix")
plt.tight_layout()
plt.savefig("correlation_heatmap.png", dpi=150)
plt.show()

# Pairplot
g = sns.pairplot(df)
g.savefig("pairplot.png", dpi=150)
plt.show()

# %% [markdown]
# # 3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import string

df = pd.read_csv("data_2241.csv", index_col=0)

# Rename columns to letters: A, B, C, ...
df.columns = list(string.ascii_uppercase[:len(df.columns)])

# Correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap="coolwarm", center=0)
plt.title("Correlation Matrix")
plt.tight_layout()
plt.savefig("correlation_heatmap.png", dpi=150)
plt.show()

# Pairplot
g = sns.pairplot(df)
g.savefig("pairplot.png", dpi=150)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import string

df = pd.read_csv("data_2243.csv", index_col=0)

# Rename columns to letters: A, B, C, ...
df.columns = list(string.ascii_uppercase[:len(df.columns)])

# Correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap="coolwarm", center=0)
plt.title("Correlation Matrix")
plt.tight_layout()
plt.savefig("correlation_heatmap.png", dpi=150)
plt.show()

# Pairplot
g = sns.pairplot(df)
g.savefig("pairplot.png", dpi=150)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import string

df = pd.read_csv("data_2245.csv", index_col=0)

# Rename columns to letters: A, B, C, ...
df.columns = list(string.ascii_uppercase[:len(df.columns)])

# Correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap="coolwarm", center=0)
plt.title("Correlation Matrix")
plt.tight_layout()
plt.savefig("correlation_heatmap.png", dpi=150)
plt.show()

# Pairplot
g = sns.pairplot(df)
g.savefig("pairplot.png", dpi=150)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import string

df = pd.read_csv("data_2328.csv", index_col=0)

# Rename columns to letters: A, B, C, ...
df.columns = list(string.ascii_uppercase[:len(df.columns)])

# Correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap="coolwarm", center=0)
plt.title("Correlation Matrix")
plt.tight_layout()
plt.savefig("correlation_heatmap.png", dpi=150)
plt.show()

# Pairplot
g = sns.pairplot(df)
g.savefig("pairplot.png", dpi=150)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import string

df = pd.read_csv("data_2332.csv", index_col=0)

# Rename columns to letters: A, B, C, ...
df.columns = list(string.ascii_uppercase[:len(df.columns)])

# Correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap="coolwarm", center=0)
plt.title("Correlation Matrix")
plt.tight_layout()
plt.savefig("correlation_heatmap.png", dpi=150)
plt.show()

# Pairplot
g = sns.pairplot(df)
g.savefig("pairplot.png", dpi=150)
plt.show()

# %%
df = pd.read_csv("data_2340.csv", index_col=0)

# Rename columns to letters: A, B, C, ...
df.columns = list(string.ascii_uppercase[:len(df.columns)])

# Correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap="coolwarm", center=0)
plt.title("Correlation Matrix")
plt.tight_layout()
plt.savefig("correlation_heatmap.png", dpi=150)
plt.show()

# Pairplot
g = sns.pairplot(df)
g.savefig("pairplot.png", dpi=150)
plt.show()

# %%
df = pd.read_csv("data_2342.csv", index_col=0)

# Rename columns to letters: A, B, C, ...
df.columns = list(string.ascii_uppercase[:len(df.columns)])

# Correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap="coolwarm", center=0)
plt.title("Correlation Matrix")
plt.tight_layout()
plt.savefig("correlation_heatmap.png", dpi=150)
plt.show()

# Pairplot
g = sns.pairplot(df)
g.savefig("pairplot.png", dpi=150)
plt.show()

# %%
df = pd.read_csv("data_2344.csv", index_col=0)

# Rename columns to letters: A, B, C, ...
df.columns = list(string.ascii_uppercase[:len(df.columns)])

# Correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap="coolwarm", center=0)
plt.title("Correlation Matrix")
plt.tight_layout()
plt.savefig("correlation_heatmap.png", dpi=150)
plt.show()

# Pairplot
g = sns.pairplot(df)
g.savefig("pairplot.png", dpi=150)
plt.show()

# %%
df = pd.read_csv("data_2345.csv", index_col=0)

# Rename columns to letters: A, B, C, ...
df.columns = list(string.ascii_uppercase[:len(df.columns)])

# Correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap="coolwarm", center=0)
plt.title("Correlation Matrix")
plt.tight_layout()
plt.savefig("correlation_heatmap.png", dpi=150)
plt.show()

# Pairplot
g = sns.pairplot(df)
g.savefig("pairplot.png", dpi=150)
plt.show()

# %%
df = pd.read_csv("data_2346.csv", index_col=0)

# Rename columns to letters: A, B, C, ...
df.columns = list(string.ascii_uppercase[:len(df.columns)])

# Correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap="coolwarm", center=0)
plt.title("Correlation Matrix")
plt.tight_layout()
plt.savefig("correlation_heatmap.png", dpi=150)
plt.show()

# Pairplot
g = sns.pairplot(df)
g.savefig("pairplot.png", dpi=150)
plt.show()
